# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# mpl.use("pgf")
mpl.rcParams["text.usetex"] = True
mpl.rcParams["pgf.rcfonts"] = False
mpl.rcParams["font.family"] = "sans-serif"
mpl.rcParams["pgf.preamble"] = (
    "\\usepackage{unicode-math}\\usepackage[deluxe]{luatexja}\\setmainfont{Fira Sans}\\setmathfont{Fira Math}"
)
mpl.rcParams["pgf.texsystem"] = "lualatex"

# %%
fig, ax = plt.subplots(figsize=(3, 2))
ax.plot([-1, 1], [10, 100])
ax.set(xlabel="X", ylabel="Y", title="あいうa $\\sqrt{2} 10^5$", yscale="log")
fig
# Out:
# Font 'default' does not have a glyph for '\u3042' [U+3042], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3044' [U+3044], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3046' [U+3046], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3042' [U+3042], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3044' [U+3044], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3046' [U+3046], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3042' [U+3042], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3044' [U+3044], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3046' [U+3046], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u3042' [U+3042], substituting with a dummy symbol.
# ...

# %%
fig.savefig("a.pgf", backend="pgf")
